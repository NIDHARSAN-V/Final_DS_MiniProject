# %%
do the fetaure removeal first then feature transformation

# %%
Later add the testing part in here

# %%
# 1. Feature Creation
# combining columns
# ratios, scores, aggregations
# 2. Feature Transformation ⭐ (your question)
# scaling (StandardScaler, MinMaxScaler)
# log transformation
# encoding (label, one-hot)
# binning (bucketing like days_bucket)
# normalization
# 3. Feature Selection
# chi-square test
# t-test / Mann-Whitney
# correlation filtering
# VIF removal
