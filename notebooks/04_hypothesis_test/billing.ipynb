# %%
import pandas as pd

# %%
df_billing = pd.read_csv("../../dataset/03_EDA/billings/billings_eda.csv")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_45264\2940886318.py:1: DtypeWarning: Columns (10,11,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_billing = pd.read_csv("../../dataset/03_EDA/billings/billings_eda.csv")

# %%
print(df_billing.columns)
print(len(df_billing.columns))
# Out:
# Index(['Co_Ref', 'Renewal_Month', 'Discount_Amount', 'Sustainability_Score',
#        'Total_Renewal_Score_New', 'Last_Years_Price', 'Auto_Renewal_Score',
#        'Status_Scores', 'Anchoring_Score', 'Tenure_Scores',
#        'Proforma_Auto_Renewal', 'Proforma_World_Pay_Token', 'Proforma_Date',
#        'Current_Anchorings', 'Current_Anchor_List', 'Payment_Timeframe',
#        'Registration_Date', 'Proforma_Account_Stage', 'Proforma_Audit_Status',
#        'Current_Auto_Renewal_Flag', 'Current_World_Pay_Token',
#        'Renewal_Score_At_Release', 'Proforma_Membership_Status',
#        'Proforma_Approved_Lists', 'Tenure_Years', 'Band',
#        'Prospect_Renewal_Date', 'Closed_Date', 'Prospect_Status',
#        'Starting_Net', 'Starting_Vat', 'Starting_Gross',
#        'Starting_Membership_Net', 'Starting_Package_Net', 'Starting_PQQ_Net',
#        'Gross', 'Membership_Net', 'Package_Net', 'PQQNet', 'Total_Net_Paid',
# ...

# %%
# df_billing = df_billing.drop(columns=[
#     'Start_Window',
#     'End_Window',
#     'Prospect_Outcome'
# ])

# len(df_billing.columns)

# %%
sig=[]
not_sig=[]

# %% [markdown]
# # Hypothesis Testing

# %%
# 1. Connection Group vs Churn
# H0: Connection Group has no association with churn
# H1: Connection Group significantly affects churn

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Initialize lists (IMPORTANT to avoid NameError)
sig = []
not_sig = []

# Ensure no missing values in key columns
data = df_billing[['Connection_Group', 'target']].dropna()

# Create contingency table
contingency_table = pd.crosstab(data['Connection_Group'], data['target'])

# Chi-Square Test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Results
print("📊 Chi-Square Test: Connection_Group vs Churn")
print("-" * 50)
print("Chi2 Statistic :", chi2)
print("Degrees of Freedom :", dof)
print("P-value :", p)

print("\nContingency Table:\n", contingency_table)
print("\nExpected Frequencies:\n", expected)

# Decision
alpha = 0.05
feature = "Connection_Group"

if p < alpha:
    print("\n✅ Reject H0: Connection Group significantly affects churn")
    sig.append(feature)
else:
    print("\n❌ Fail to Reject H0: No significant association between Connection Group and churn")
    not_sig.append(feature)
# Out:
# 📊 Chi-Square Test: Connection_Group vs Churn
# --------------------------------------------------
# Chi2 Statistic : 4163.0071666889135
# Degrees of Freedom : 5
# P-value : 0.0
#
# Contingency Table:
#  target                0     1
# Connection_Group
# 1                 30471  4964
# 10+                7613   174
# 2                 16636  1531
# 3                  9251   579
# 4-9               18680   755
# independent       18524  4594
#
# Expected Frequencies:
#  [[31511.58567134  3923.41432866]
#  [ 6924.81212425   862.18787575]
#  [16155.52354709  2011.47645291]
#  [ 8741.60821643  1088.39178357]
#  [17283.12875752  2151.87124248]
#  [20558.34168337  2559.65831663]]
#
# ✅ Reject H0: Connection Group significantly affects churn

# %%
# 2. Plan Type / Band vs Churn
# H0: Plan Type (Band) is independent of churn
# H1: Plan Type (Band) is associated with churn

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Initialize tracking lists (if not already created)
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Band', 'target']].dropna()

# Contingency table
contingency_table = pd.crosstab(data['Band'], data['target'])

# Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print results
print("📊 Chi-Square Test: Band vs Churn")
print("-" * 50)
print("Chi2 Statistic :", chi2)
print("Degrees of Freedom :", dof)
print("P-value :", p)

print("\nContingency Table:\n", contingency_table)
print("\nExpected Frequencies:\n", expected)

# Decision
alpha = 0.05
feature = "Band"

if p < alpha:
    print("\n✅ Reject H0: Band is associated with churn")
    sig.append(feature)
else:
    print("\n❌ Fail to Reject H0: Band is independent of churn")
    not_sig.append(feature)
# Out:
# 📊 Chi-Square Test: Band vs Churn
# --------------------------------------------------
# Chi2 Statistic : 2582.094628018041
# Degrees of Freedom : 13
# P-value : 0.0
#
# Contingency Table:
#  target       0     1
# Band
# Band A    2746   777
# Band B   25199  5293
# Band C1  20624  2544
# Band C2  13519  1218
# Band D   16463  1257
# Band E    8422   579
# Band F    2054   139
# Band F1   5097   336
# Band F2   2742   197
# Band G    2093   149
# Band H     717    52
# Band I     335    30
# Band J     338    24
# Group      876    54
#
# Expected Frequencies:
#  [[ 3131.6689938    391.3310062 ]
#  [27104.98182201  3387.01817799]
#  [20594.52377189  2573.47622811]
#  [13100.0300771   1636.9699229 ]
#  [15751.68168326  1968.31831674]
#  [ 8001.17871507   999.82128493]
#  [ 1949.40394647   243.59605353]
#  [ 4829.5082723    603.4917277 ]
#  [ 2612.53907828   326.46092172]
#  [ 1992.96107979   249.03892021]
#  [  683.58031684    85.41968316]
#  [  324.4561972     40.5438028 ]
# ...

# %%
# 3. Billing Cycle / Tenure Group vs Churn
# H0: Billing Cycle / Tenure Group does not affect churn
# H1: Billing Cycle / Tenure Group affects churn

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Tenure_Group', 'target']].dropna()

# Contingency table
contingency_table = pd.crosstab(data['Tenure_Group'], data['target'])

# Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Results
print("📊 Chi-Square Test: Tenure_Group vs Churn")
print("-" * 50)
print("Chi2 Statistic :", chi2)
print("Degrees of Freedom :", dof)
print("P-value :", p)

print("\nContingency Table:\n", contingency_table)
print("\nExpected Frequencies:\n", expected)

# Decision
alpha = 0.05
feature = "Tenure_Group"

if p < alpha:
    print("\n✅ Reject H0: Tenure Group significantly affects churn")
    sig.append(feature)
else:
    print("\n❌ Fail to Reject H0: Tenure Group does not affect churn")
    not_sig.append(feature)

# Summary tracking
print("\n==============================")
print("SIGNIFICANT FEATURES:", sig)
print("NON-SIGNIFICANT FEATURES:", not_sig)
print("==============================")
# Out:
# 📊 Chi-Square Test: Tenure_Group vs Churn
# --------------------------------------------------
# Chi2 Statistic : 3630.3593579341764
# Degrees of Freedom : 3
# P-value : 0.0
#
# Contingency Table:
#  target            0     1
# Tenure_Group
# 1             14095  3931
# 2             11086  2112
# 3              8858  1415
# 4+            66333  5089
#
# Expected Frequencies:
#  [[16023.04016153  2002.95983847]
#  [11731.50360878  1466.49639122]
#  [ 9131.51512146  1141.48487854]
#  [63485.94110823  7936.05889177]]
#
# ✅ Reject H0: Tenure Group significantly affects churn
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group']
# NON-SIGNIFICANT FEATURES: []
# ...

# %%
# 4. Payment Method vs Churn
# H0: Payment Method is independent of churn
# H1: Payment Method influences churn

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Payment_Method', 'target']].dropna()

# Contingency table
contingency_table = pd.crosstab(data['Payment_Method'], data['target'])

# Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Results
print("📊 Chi-Square Test: Payment_Method vs Churn")
print("-" * 50)
print("Chi2 Statistic :", chi2)
print("Degrees of Freedom :", dof)
print("P-value :", p)

print("\nContingency Table:\n", contingency_table)
print("\nExpected Frequencies:\n", expected)

# Decision
alpha = 0.05
feature = "Payment_Method"

if p < alpha:
    print("\n✅ Reject H0: Payment Method significantly affects churn")
    sig.append(feature)
else:
    print("\n❌ Fail to Reject H0: Payment Method is independent of churn")
    not_sig.append(feature)

# Summary tracking
print("\n==============================")
print("SIGNIFICANT FEATURES:", sig)
print("NON-SIGNIFICANT FEATURES:", not_sig)
print("==============================")
# Out:
# 📊 Chi-Square Test: Payment_Method vs Churn
# --------------------------------------------------
# Chi2 Statistic : 68301.1913652539
# Degrees of Freedom : 4
# P-value : 0.0
#
# Contingency Table:
#  target              0     1
# Payment_Method
# BACS            33191     0
# CARD            66265  4836
# CHEQUE             71     0
# UNKNOWN             0  7832
# WORLD PAY        1699     0
#
# Expected Frequencies:
#  [[2.94992903e+04 3.69170973e+03]
#  [6.31927040e+04 7.90829603e+03]
#  [6.31029378e+01 7.89706218e+00]
#  [6.96087618e+03 8.71123817e+02]
#  [1.51002664e+03 1.88973361e+02]]
#
# ✅ Reject H0: Payment Method significantly affects churn
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group', 'Payment_Method']
# NON-SIGNIFICANT FEATURES: []
# ...

# %%
# 5. Auto-pay Enabled vs Churn
# H0: Auto-pay status has no relationship with churn
# H1: Auto-pay status is associated with churn

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Current_Auto_Renewal_Flag', 'target']].dropna()

# Contingency table
contingency_table = pd.crosstab(data['Current_Auto_Renewal_Flag'], data['target'])

# Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Results
print("📊 Chi-Square Test: Auto-Renewal Flag vs Churn")
print("-" * 50)
print("Chi2 Statistic :", chi2)
print("Degrees of Freedom :", dof)
print("P-value :", p)

print("\nContingency Table:\n", contingency_table)
print("\nExpected Frequencies:\n", expected)

# Decision
alpha = 0.05
feature = "Current_Auto_Renewal_Flag"

if p < alpha:
    print("\n✅ Reject H0: Auto-pay status significantly affects churn")
    sig.append(feature)
else:
    print("\n❌ Fail to Reject H0: Auto-pay status is independent of churn")
    not_sig.append(feature)

# Summary tracking
print("\n==============================")
print("SIGNIFICANT FEATURES:", sig)
print("NON-SIGNIFICANT FEATURES:", not_sig)
print("==============================")
# Out:
# 📊 Chi-Square Test: Auto-Renewal Flag vs Churn
# --------------------------------------------------
# Chi2 Statistic : 2380.948863117623
# Degrees of Freedom : 1
# P-value : 0.0
#
# Contingency Table:
#  target                         0      1
# Current_Auto_Renewal_Flag
# n                           5004   2029
# y                          96222  10639
#
# Expected Frequencies:
#  [[ 6250.74593921   782.25406079]
#  [94975.25406079 11885.74593921]]
#
# ✅ Reject H0: Auto-pay status significantly affects churn
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group', 'Payment_Method', 'Current_Auto_Renewal_Flag']
# NON-SIGNIFICANT FEATURES: []
# ...

# %%
# 6. Region / Location vs Churn
# H0: Region has no effect on churn
# H1: Region affects churn behavior

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Anchor_Group', 'target']].dropna()

# Contingency table
contingency_table = pd.crosstab(data['Anchor_Group'], data['target'])

# Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Results
print("📊 Chi-Square Test: Anchor_Group (Region) vs Churn")
print("-" * 50)
print("Chi2 Statistic :", chi2)
print("Degrees of Freedom :", dof)
print("P-value :", p)

print("\nContingency Table:\n", contingency_table)
print("\nExpected Frequencies:\n", expected)

# Decision
alpha = 0.05
feature = "Anchor_Group"

if p < alpha:
    print("\n✅ Reject H0: Anchor significantly affects churn")
    sig.append(feature)
else:
    print("\n❌ Fail to Reject H0: Anchor is independent of churn")
    not_sig.append(feature)

# Summary tracking
print("\n==============================")
print("SIGNIFICANT FEATURES:", sig)
print("NON-SIGNIFICANT FEATURES:", not_sig)
print("==============================")
# Out:
# 📊 Chi-Square Test: Anchor_Group (Region) vs Churn
# --------------------------------------------------
# Chi2 Statistic : 4163.0071666889135
# Degrees of Freedom : 5
# P-value : 0.0
#
# Contingency Table:
#  target            0     1
# Anchor_Group
# 1             30471  4964
# 10+            7613   174
# 2             16636  1531
# 3              9251   579
# 4-9           18680   755
# independent   18524  4594
#
# Expected Frequencies:
#  [[31511.58567134  3923.41432866]
#  [ 6924.81212425   862.18787575]
#  [16155.52354709  2011.47645291]
#  [ 8741.60821643  1088.39178357]
#  [17283.12875752  2151.87124248]
#  [20558.34168337  2559.65831663]]
#
# ✅ Reject H0: Anchor significantly affects churn
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group', 'Payment_Method', 'Current_Auto_Renewal_Flag', 'Anchor_Group']
# NON-SIGNIFICANT FEATURES: []
# ...

# %%
# 7. Contract Type / Account Stage vs Churn
# H0: Contract Type / Account Stage is independent of churn
# H1: Contract Type / Account Stage is associated with churn

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Proforma_Account_Stage', 'target']].dropna()

# Contingency table
contingency_table = pd.crosstab(data['Proforma_Account_Stage'], data['target'])

# Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Results
print("📊 Chi-Square Test: Proforma_Account_Stage vs Churn")
print("-" * 50)
print("Chi2 Statistic :", chi2)
print("Degrees of Freedom :", dof)
print("P-value :", p)

print("\nContingency Table:\n", contingency_table)
print("\nExpected Frequencies:\n", expected)

# Decision
alpha = 0.05
feature = "Proforma_Account_Stage"

if p < alpha:
    print("\n✅ Reject H0: Account Stage significantly affects churn")
    sig.append(feature)
else:
    print("\n❌ Fail to Reject H0: Account Stage is independent of churn")
    not_sig.append(feature)

# Summary tracking
print("\n==============================")
print("SIGNIFICANT FEATURES:", sig)
print("NON-SIGNIFICANT FEATURES:", not_sig)
print("==============================")
# Out:
# 📊 Chi-Square Test: Proforma_Account_Stage vs Churn
# --------------------------------------------------
# Chi2 Statistic : 8715.49496831016
# Degrees of Freedom : 6
# P-value : 0.0
#
# Contingency Table:
#  target                      0     1
# Proforma_Account_Stage
# Membership Only         11294  4830
# Published               67950  4459
# Renewal Process         11556  1319
# Retired                     0     2
# Suspended                 767   104
# Vetting                  1642   745
# vetting                     0     1
#
# Expected Frequencies:
#  [[1.43586154e+04 1.76538459e+03]
#  [6.44810830e+04 7.92791696e+03]
#  [1.14653419e+04 1.40965806e+03]
#  [1.78102399e+00 2.18976010e-01]
#  [7.75635948e+02 9.53640524e+01]
#  [2.12565213e+03 2.61347868e+02]
#  [8.90511995e-01 1.09488005e-01]]
#
# ✅ Reject H0: Account Stage significantly affects churn
#
# ...

# %%
# 9. Tenure (VERY IMPORTANT) vs Churn H0: Tenure distribution is the same for churn and non-churn users H1: Tenure differs significantly between churned and non-churned users

# %%
import pandas as pd
from scipy.stats import ttest_ind

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Tenure_Years', 'target']].dropna()

# Split groups
churn = data[data['target'] == 1]['Tenure_Years']
non_churn = data[data['target'] == 0]['Tenure_Years']

# Safety check
if len(churn) == 0 or len(non_churn) == 0:
    print("❌ One group is empty. Check target encoding.")
else:
    # Welch's t-test (unequal variance)
    t_stat, p = ttest_ind(churn, non_churn, equal_var=False)

    print("📊 T-Test: Tenure vs Churn")
    print("-" * 50)
    print("T-Statistic:", t_stat)
    print("P-value:", p)

    print("\nMean (Churn):", churn.mean())
    print("Mean (Non-Churn):", non_churn.mean())

    feature = "Tenure_Years"
    alpha = 0.05

    if p < alpha:
        print("\n✅ Reject H0: Tenure mean differs between churn groups")
        sig.append(feature)
    else:
        print("\n❌ Fail to Reject H0: No significant difference in tenure mean")
        not_sig.append(feature)

    print("\n==============================")
    print("SIGNIFICANT FEATURES:", sig)
    print("NON-SIGNIFICANT FEATURES:", not_sig)
    print("==============================")
# Out:
# 📊 T-Test: Tenure vs Churn
# --------------------------------------------------
# T-Statistic: -66.6608638822599
# P-value: 0.0
#
# Mean (Churn): 4.372519327329242
# Mean (Non-Churn): 7.17007731239788
#
# ✅ Reject H0: Tenure mean differs between churn groups
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group', 'Payment_Method', 'Current_Auto_Renewal_Flag', 'Anchor_Group', 'Proforma_Account_Stage', 'Tenure_Years']
# NON-SIGNIFICANT FEATURES: []
# ...

# %%
# 10. Outstanding Amount / Price Increase % vs Churn
# H0: Outstanding Amount / Price Increase % has no difference between churn groups
# H1: Outstanding Amount / Price Increase % differs between churn groups

# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

features = ['price_increase_pct', 'Total_Net_Paid']  # add outstanding if available

for feature in features:
    print(f"\n📊 Mann–Whitney U Test: {feature} vs Churn")
    print("-" * 60)

    data = df_billing[[feature, 'target']].dropna()

    churn = data[data['target'] == 1][feature]
    non_churn = data[data['target'] == 0][feature]

    if len(churn) == 0 or len(non_churn) == 0:
        print("❌ Skipped: One group is empty")
        continue

    u_stat, p = mannwhitneyu(churn, non_churn, alternative='two-sided')

    print("U-Statistic:", u_stat)
    print("P-value:", p)

    print("Median (Churn):", churn.median())
    print("Median (Non-Churn):", non_churn.median())

    alpha = 0.05

    if p < alpha:
        print("✅ Reject H0")
        sig.append(feature)
    else:
        print("❌ Fail to Reject H0")
        not_sig.append(feature)

print("\n==============================")
print("SIGNIFICANT FEATURES:", sig)
print("NON-SIGNIFICANT FEATURES:", not_sig)
print("==============================")
# Out:
# 📊 Mann–Whitney U Test: price_increase_pct vs Churn
# ------------------------------------------------------------
# ❌ Skipped: One group is empty
#
# 📊 Mann–Whitney U Test: Total_Net_Paid vs Churn
# ------------------------------------------------------------
# ❌ Skipped: One group is empty
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group', 'Payment_Method', 'Current_Auto_Renewal_Flag', 'Anchor_Group', 'Proforma_Account_Stage', 'Tenure_Years']
# NON-SIGNIFICANT FEATURES: []
# ...

# %%
# Hypotheses
# H0: Mean Membership_Net is the same for churn and non-churn users
# H1: Mean Membership_Net differs between churn groups

# %%
import pandas as pd
from scipy.stats import ttest_ind

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Membership_Net', 'target']].dropna()

# Split groups
churn = data[data['target'] == 1]['Membership_Net']
non_churn = data[data['target'] == 0]['Membership_Net']

# Safety check
if len(churn) == 0 or len(non_churn) == 0:
    print("❌ One group is empty. Check target encoding or missing values.")
else:
    # Welch’s t-test (robust for unequal variance)
    t_stat, p = ttest_ind(churn, non_churn, equal_var=False)

    print("📊 T-Test: Membership_Net vs Churn")
    print("-" * 50)
    print("T-Statistic:", t_stat)
    print("P-value:", p)

    print("\nMean (Churn):", churn.mean())
    print("Mean (Non-Churn):", non_churn.mean())

    feature = "Membership_Net"
    alpha = 0.05

    if p < alpha:
        print("\n✅ Reject H0: Membership_Net significantly differs between churn groups")
        sig.append(feature)
    else:
        print("\n❌ Fail to Reject H0: No significant difference in Membership_Net")

        not_sig.append(feature)

    print("\n==============================")
    print("SIGNIFICANT FEATURES:", sig)
    print("NON-SIGNIFICANT FEATURES:", not_sig)
    print("==============================")
# Out:
# 📊 T-Test: Membership_Net vs Churn
# --------------------------------------------------
# T-Statistic: -56.98545241104686
# P-value: 0.0
#
# Mean (Churn): 626.3207609725292
# Mean (Non-Churn): 858.9251902673226
#
# ✅ Reject H0: Membership_Net significantly differs between churn groups
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group', 'Payment_Method', 'Current_Auto_Renewal_Flag', 'Anchor_Group', 'Proforma_Account_Stage', 'Tenure_Years', 'Membership_Net']
# NON-SIGNIFICANT FEATURES: []
# ...

# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# Initialize tracking lists safely
try:
    sig
except NameError:
    sig = []
    not_sig = []

# Clean data
data = df_billing[['Starting_Vat', 'target']].dropna()

# Split groups
churn = data[data['target'] == 1]['Starting_Vat']
non_churn = data[data['target'] == 0]['Starting_Vat']

# Safety check
if len(churn) == 0 or len(non_churn) == 0:
    print("❌ One group is empty. Check target encoding or missing values.")
else:
    # Mann-Whitney U test (safe for skewed financial data)
    u_stat, p = mannwhitneyu(churn, non_churn, alternative='two-sided')

    print("📊 Mann–Whitney U Test: Starting_Vat vs Churn")
    print("-" * 50)
    print("U-Statistic:", u_stat)
    print("P-value:", p)

    print("\nMedian (Churn):", churn.median())
    print("Median (Non-Churn):", non_churn.median())

    feature = "Starting_Vat"
    alpha = 0.05

    if p < alpha:
        print("\n✅ Reject H0: Starting_Vat differs between churn groups")
        sig.append(feature)
    else:
        print("\n❌ Fail to Reject H0: No significant difference in Starting_Vat")
        not_sig.append(feature)

    print("\n==============================")
    print("SIGNIFICANT FEATURES:", sig)
    print("NON-SIGNIFICANT FEATURES:", not_sig)
    print("==============================")
# Out:
# 📊 Mann–Whitney U Test: Starting_Vat vs Churn
# --------------------------------------------------
# U-Statistic: 475404309.0
# P-value: 0.0
#
# Median (Churn): 149.8
# Median (Non-Churn): 186.8
#
# ✅ Reject H0: Starting_Vat differs between churn groups
#
# ...
# SIGNIFICANT FEATURES: ['Connection_Group', 'Band', 'Tenure_Group', 'Payment_Method', 'Current_Auto_Renewal_Flag', 'Anchor_Group', 'Proforma_Account_Stage', 'Tenure_Years', 'Membership_Net', 'Starting_Vat']
# NON-SIGNIFICANT FEATURES: []
# ...

# %% [markdown]
# # Due to class imbalance and sparcity i get wrong test inmany cases
